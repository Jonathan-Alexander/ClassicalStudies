# %%
import pandas as pd
import textstat
# For timing
from time import clock
from math import floor

from text_processing import get_full_text_by_pmcid

# %%
# Index of all entries
df = pd.read_csv('PMC-ids.csv')
# Out:
# /Users/henrywang/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (3,4,5,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
# Bash script to generate this txt file
retracted_df = pd.read_csv('pubmed_retracted_pmcids.txt', header=None, skip_blank_lines=False)

# %%
def clean(pmcid):
    pmcid = pmcid.split()[1]
    pmcid = pmcid.split(';')[0]
    return pmcid

# %%
# Rename column
retracted_df.columns = ['PMCID']
retracted_df['PMCID'] = retracted_df['PMCID'].map(lambda r: clean(r))

# %%
# Dataframe of open access subset
oa_df = pd.read_csv('oa_file_list.csv')

oa_df.columns

# Rename Accession ID -> PMCID to match
oa_df = oa_df.rename(columns={'Accession ID': 'PMCID'})

# %%
# Contains things in open subset AND in the main PMC-id csv
joined = df.merge(oa_df, how='inner', left_on='PMCID', right_on='PMCID')

# %%
# Combine open subset with retracted table
oa_retracted_df = joined.merge(retracted_df, how='inner', left_on='PMCID', right_on='PMCID')

oa_retracted_df.shape

oa_retracted_df.head()
# Out:
#             Journal Title ISSN      eISSN  Year Volume Issue Page  \
# 0              Mol Cancer  NaN  1476-4598  2003      2   NaN   28
# 1              Mol Cancer  NaN  1476-4598  2003      2   NaN   33
# 2  Reprod Biol Endocrinol  NaN  1477-7827  2003      1   NaN  125
# 3       Biomed Eng Online  NaN  1475-925X  2004      3   NaN   13
# 4           BMC Evol Biol  NaN  1471-2148  2004      4   NaN   18
#
#                        DOI      PMCID      PMID_x Manuscript Id Release Date  \
# 0   10.1186/1476-4598-2-28  PMC184456  12935295.0           NaN         live
# 1   10.1186/1476-4598-2-33  PMC222989  14572313.0           NaN         live
# 2  10.1186/1477-7827-1-125  PMC317376  14678567.0           NaN         live
# 3   10.1186/1475-925X-3-13  PMC419711  15125779.0           NaN         live
# 4   10.1186/1471-2148-4-18  PMC459214  15222900.0           NaN         live
#
#                                 File  \
# 0  oa_package/b9/6e/PMC184456.tar.gz
# 1  oa_package/18/49/PMC222989.tar.gz
# 2  oa_package/3f/83/PMC317376.tar.gz
# 3  oa_package/90/77/PMC419711.tar.gz
# 4  oa_package/c4/42/PMC459214.tar.gz
#
#                              Article Citation  \
# 0                Mol Cancer. 2003 Aug 7; 2:28
# 1               Mol Cancer. 2003 Sep 23; 2:33
# 2  Reprod Biol Endocrinol. 2003 Dec 16; 1:125
# 3         Biomed Eng Online. 2004 May 5; 3:13
# 4            BMC Evol Biol. 2004 Jun 28; 4:18
#
#   Last Updated (YYYY-MM-DD HH:MM:SS)      PMID_y     License
# 0                2012-09-17 12:08:47  12935295.0  NO-CC CODE
# 1                2012-09-17 12:08:47  14572313.0  NO-CC CODE
# 2                2015-04-17 20:12:16  14678567.0  NO-CC CODE
# 3                2014-11-05 19:21:09  15125779.0  NO-CC CODE
# 4                2018-12-23 03:55:57  15222900.0  NO-CC CODE

# %%
# Clean table for duplicate columns PMID_x/PMID_y => True means they are duplicates
(oa_retracted_df['PMID_x'] == oa_retracted_df['PMID_y']).all()

# axis = 1 means drop column
oa_retracted_df.drop(labels=['PMID_y'], axis=1, inplace=True)

# Rename PMID_x -> PMID
oa_retracted_df = oa_retracted_df.rename(columns={'PMID_x': 'PMID'})
oa_retracted_df.head()
# Out:
#             Journal Title ISSN      eISSN  Year Volume Issue Page  \
# 0              Mol Cancer  NaN  1476-4598  2003      2   NaN   28
# 1              Mol Cancer  NaN  1476-4598  2003      2   NaN   33
# 2  Reprod Biol Endocrinol  NaN  1477-7827  2003      1   NaN  125
# 3       Biomed Eng Online  NaN  1475-925X  2004      3   NaN   13
# 4           BMC Evol Biol  NaN  1471-2148  2004      4   NaN   18
#
#                        DOI      PMCID        PMID Manuscript Id Release Date  \
# 0   10.1186/1476-4598-2-28  PMC184456  12935295.0           NaN         live
# 1   10.1186/1476-4598-2-33  PMC222989  14572313.0           NaN         live
# 2  10.1186/1477-7827-1-125  PMC317376  14678567.0           NaN         live
# 3   10.1186/1475-925X-3-13  PMC419711  15125779.0           NaN         live
# 4   10.1186/1471-2148-4-18  PMC459214  15222900.0           NaN         live
#
#                                 File  \
# 0  oa_package/b9/6e/PMC184456.tar.gz
# 1  oa_package/18/49/PMC222989.tar.gz
# 2  oa_package/3f/83/PMC317376.tar.gz
# 3  oa_package/90/77/PMC419711.tar.gz
# 4  oa_package/c4/42/PMC459214.tar.gz
#
#                              Article Citation  \
# 0                Mol Cancer. 2003 Aug 7; 2:28
# 1               Mol Cancer. 2003 Sep 23; 2:33
# 2  Reprod Biol Endocrinol. 2003 Dec 16; 1:125
# 3         Biomed Eng Online. 2004 May 5; 3:13
# 4            BMC Evol Biol. 2004 Jun 28; 4:18
#
#   Last Updated (YYYY-MM-DD HH:MM:SS)     License
# 0                2012-09-17 12:08:47  NO-CC CODE
# 1                2012-09-17 12:08:47  NO-CC CODE
# 2                2015-04-17 20:12:16  NO-CC CODE
# 3                2014-11-05 19:21:09  NO-CC CODE
# 4                2018-12-23 03:55:57  NO-CC CODE

# %%
# Write to file
# oa_retracted_df.to_csv('oa-retracted-table.csv', sep=',', encoding='utf-8')

# %%
table = joined.merge(retracted_df, how='outer', left_on='PMCID', right_on='PMCID', indicator=True)

table.head()

# table[table['_merge'] == 'both'] # Retracted and in open access subset

# table[table['_merge'] == 'right_only'] # Retracted but not in open access subset

# table[table['_merge'] == 'left_only'] # Not retracted but in open access subset
# Out:
#        Journal Title       ISSN      eISSN  Year Volume Issue Page  \
# 0  Breast Cancer Res  1465-5411  1465-542X  2000      3     1   55
# 1  Breast Cancer Res  1465-5411  1465-542X  2000      3     1   61
# 2  Breast Cancer Res  1465-5411  1465-542X  2000      3     1   66
# 3  Breast Cancer Res  1465-5411  1465-542X  1999      2     1   59
# 4  Breast Cancer Res  1465-5411  1465-542X  1999      2     1   64
#
#              DOI     PMCID      PMID_x Manuscript Id Release Date  \
# 0            NaN  PMC13900  11250746.0           NaN         live
# 1            NaN  PMC13901  11250747.0           NaN         live
# 2            NaN  PMC13902  11250748.0           NaN         live
# 3  10.1186/bcr29  PMC13911  11056684.0           NaN         live
# 4            NaN  PMC13912  11400682.0           NaN         live
#
#                                File  \
# 0  oa_package/08/e0/PMC13900.tar.gz
# 1  oa_package/b0/ac/PMC13901.tar.gz
# 2  oa_package/f7/98/PMC13902.tar.gz
# 3  oa_package/9c/7f/PMC13911.tar.gz
# 4  oa_package/c6/fb/PMC13912.tar.gz
#
#                              Article Citation  \
# 0   Breast Cancer Res. 2001 Nov 2; 3(1):55-60
# 1   Breast Cancer Res. 2001 Nov 9; 3(1):61-65
# 2   Breast Cancer Res. 2001 Nov 8; 3(1):66-75
# 3  Breast Cancer Res. 2000 Nov 16; 2(1):59-63
# 4   Breast Cancer Res. 2000 Dec 6; 2(1):64-72
#
#   Last Updated (YYYY-MM-DD HH:MM:SS)      PMID_y     License     _merge
# 0                2017-04-26 12:15:50  11250746.0  NO-CC CODE  left_only
# 1                2016-01-20 10:58:46  11250747.0  NO-CC CODE  left_only
# 2                2006-02-02 19:37:52  11250748.0  NO-CC CODE  left_only
# 3                2013-03-17 14:00:52  11056684.0  NO-CC CODE  left_only
# 4                2013-03-17 14:00:52  11400682.0  NO-CC CODE  left_only

# %%
# Delete duplicate column
table.drop(['PMID_y'], axis=1, inplace=True)

# %%
# Rename duplicate column
table = table.rename(columns={'PMID_x': 'PMID'})

# %%
# Entries with "right_only" are retracted, but not indexed by PubMed
table = table[table['_merge'] != 'right_only']

# %%
# Rename
table['Retracted'] = table['_merge'] == 'both'
table.drop(['_merge'], axis=1, inplace=True)

# %%
table.head()
# Out:
#        Journal Title       ISSN      eISSN  Year Volume Issue Page  \
# 0  Breast Cancer Res  1465-5411  1465-542X  2000      3     1   55
# 1  Breast Cancer Res  1465-5411  1465-542X  2000      3     1   61
# 2  Breast Cancer Res  1465-5411  1465-542X  2000      3     1   66
# 3  Breast Cancer Res  1465-5411  1465-542X  1999      2     1   59
# 4  Breast Cancer Res  1465-5411  1465-542X  1999      2     1   64
#
#              DOI     PMCID        PMID Manuscript Id Release Date  \
# 0            NaN  PMC13900  11250746.0           NaN         live
# 1            NaN  PMC13901  11250747.0           NaN         live
# 2            NaN  PMC13902  11250748.0           NaN         live
# 3  10.1186/bcr29  PMC13911  11056684.0           NaN         live
# 4            NaN  PMC13912  11400682.0           NaN         live
#
#                                File  \
# 0  oa_package/08/e0/PMC13900.tar.gz
# 1  oa_package/b0/ac/PMC13901.tar.gz
# 2  oa_package/f7/98/PMC13902.tar.gz
# 3  oa_package/9c/7f/PMC13911.tar.gz
# 4  oa_package/c6/fb/PMC13912.tar.gz
#
#                              Article Citation  \
# 0   Breast Cancer Res. 2001 Nov 2; 3(1):55-60
# 1   Breast Cancer Res. 2001 Nov 9; 3(1):61-65
# 2   Breast Cancer Res. 2001 Nov 8; 3(1):66-75
# 3  Breast Cancer Res. 2000 Nov 16; 2(1):59-63
# 4   Breast Cancer Res. 2000 Dec 6; 2(1):64-72
#
#   Last Updated (YYYY-MM-DD HH:MM:SS)     License  Retracted
# 0                2017-04-26 12:15:50  NO-CC CODE      False
# 1                2016-01-20 10:58:46  NO-CC CODE      False
# 2                2006-02-02 19:37:52  NO-CC CODE      False
# 3                2013-03-17 14:00:52  NO-CC CODE      False
# 4                2013-03-17 14:00:52  NO-CC CODE      False

# %%
# table[(table.Retracted) & (table.ISSN.isnull())]
# Write to file
table.to_csv('full-table.csv', sep=',', encoding='utf-8', index=False)

# %% [markdown]
# ## Sampling with GroupBy

# %%
retracted = table[table['Retracted'] == True]
unretracted = table[table['Retracted'] == False]
print(unretracted.shape)
# Out:
# (2345880, 17)

# %%
# Filter so we have choose from the same journal titles
retracted_journals = set(retracted['Journal Title'])
unretracted_pop = unretracted[unretracted['Journal Title'].isin(retracted_journals)]
unretracted_journals = set(unretracted_pop['Journal Title'])

# %%
retracted_journals == unretracted_journals
# Out:
# True

# %%
unretracted_pop.shape
# Out:
# (1260979, 17)

# %%
'Breast Cancer Res' in unretracted_journals and 'Breast Cancer Res' in retracted_journals
# Out:
# True

# %%
rgb = retracted.groupby('Journal Title', group_keys=False, as_index=False) # population
# keep index for dict
r_dict = (retracted.groupby('Journal Title', group_keys=False).count()['Retracted']).to_dict() 
ugb = unretracted_pop.groupby('Journal Title', group_keys=False, as_index=False)

# %%
print(len(retracted_journals))
# Out:
# 429

# %%
print(len(unretracted_journals))
# Out:
# 429

# %%
# rgb.count()

# %%
# ugb.count()

# %%
def custom_sample(df):
    name = df.iloc[0]['Journal Title']
    n = r_dict[name]
    return df.sample(n)
control_sample = ugb.apply(custom_sample)

# %%
control_sample
# Out:
#                                      Journal Title       ISSN      eISSN  \
# 1053358                                  AIDS Care  0954-0121  1360-0451
# 838515                            ARYA Atheroscler  1735-3955  2251-6638
# 2045390             Acta Crystallogr D Struct Biol        NaN  2059-7983
# 802598   Acta Crystallogr Sect E Struct Rep Online        NaN  1600-5368
# 281606   Acta Crystallogr Sect E Struct Rep Online        NaN  1600-5368
# 292723   Acta Crystallogr Sect E Struct Rep Online        NaN  1600-5368
# 323127   Acta Crystallogr Sect E Struct Rep Online        NaN  1600-5368
# 342917   Acta Crystallogr Sect E Struct Rep Online        NaN  1600-5368
# 343177   Acta Crystallogr Sect E Struct Rep Online        NaN  1600-5368
# 947604   Acta Crystallogr Sect E Struct Rep Online        NaN  1600-5368
# 303823   Acta Crystallogr Sect E Struct Rep Online        NaN  1600-5368
# 947555   Acta Crystallogr Sect E Struct Rep Online        NaN  1600-5368
# 280441   Acta Crystallogr Sect E Struct Rep Online        NaN  1600-5368
# 292468   Acta Crystallogr Sect E Struct Rep Online        NaN  1600-5368
# 306512   Acta Crystallogr Sect E Struct Rep Online        NaN  1600-5368
# 281045   Acta Crystallogr Sect E Struct Rep Online        NaN  1600-5368
# 411194   Acta Crystallogr Sect E Struct Rep Online        NaN  1600-5368
# 287847   Acta Crystallogr Sect E Struct Rep Online        NaN  1600-5368
# 323879   Acta Crystallogr Sect E Struct Rep Online        NaN  1600-5368
# 281861   Acta Crystallogr Sect E Struct Rep Online        NaN  1600-5368
# 690612   Acta Crystallogr Sect E Struct Rep Online        NaN  1600-5368
# 365756   Acta Crystallogr Sect E Struct Rep Online        NaN  1600-5368
# 394203   Acta Crystallogr Sect E Struct Rep Online        NaN  1600-5368
# 388050   Acta Crystallogr Sect E Struct Rep Online        NaN  1600-5368
# 461935   Acta Crystallogr Sect E Struct Rep Online        NaN  1600-5368
# 523590   Acta Crystallogr Sect E Struct Rep Online        NaN  1600-5368
# 303861   Acta Crystallogr Sect E Struct Rep Online        NaN  1600-5368
# 291793   Acta Crystallogr Sect E Struct Rep Online        NaN  1600-5368
# 480744   Acta Crystallogr Sect E Struct Rep Online        NaN  1600-5368
# 304971   Acta Crystallogr Sect E Struct Rep Online        NaN  1600-5368
# ...                                            ...        ...        ...
# 2121012                           Transl Med UniSa        NaN  2239-9747
# 1320973                        Transl Neurodegener        NaN  2047-9158
# 1682460                          Transl Psychiatry        NaN  2158-3188
# 1049605                                     Trials        NaN  1745-6215
# 799147                              Trop Parasitol  2229-5070  2229-7758
# 1418231                             Trop Parasitol  2229-5070  2229-7758
# 591087                                 Tumour Biol  1010-4283  1423-0380
# 331741                                     Virol J        NaN  1743-422X
# 196132                                     Virol J        NaN  1743-422X
# 1926924          Wideochir Inne Tech Maloinwazyjne  1895-4588  2299-0054
# 1399474                           World J Nucl Med  1450-1147  1607-3312
# 568552                            World J Nucl Med  1450-1147  1607-3312
# 568510                            World J Nucl Med  1450-1147  1607-3312
# 1839005                              World J Oncol  1920-4531  1920-454X
# 215588                          World J Surg Oncol        NaN  1477-7819
# 539161                          World J Surg Oncol        NaN  1477-7819
# 1540152                         World J Surg Oncol        NaN  1477-7819
# 216018                          World J Surg Oncol        NaN  1477-7819
# 375076                          World J Surg Oncol        NaN  1477-7819
# 170998                             Yale J Biol Med  0044-0086  1551-4056
# 298927                                Yonsei Med J  0513-5796  1976-2437
# 175187                                Yonsei Med J  0513-5796  1976-2437
# 845208                                Yonsei Med J  0513-5796  1976-2437
# 175168                                Yonsei Med J  0513-5796  1976-2437
# 176650                                Yonsei Med J  0513-5796  1976-2437
# 1231335                               Yonsei Med J  0513-5796  1976-2437
# 665051                                Yonsei Med J  0513-5796  1976-2437
# 375076   PMC3171710  21835024.0           NaN         live
# 170998   PMC2601584  21433726.0           NaN         live
# 298927   PMC2995957  20879059.0           NaN         live
# 175187   PMC2615335  18581599.0           NaN         live
# 845208   PMC4075379  24954349.0           NaN         live
# 175168   PMC2615316  18452276.0           NaN         live
# 176650   PMC2628138  17963329.0           NaN         live
# 1231335  PMC4740548  26847308.0           NaN         live
# 665051   PMC3743197  23918580.0           NaN         live
# 1626017  PMC5332158  28139976.0           NaN         live
# 1408592  PMC5035143  27525481.0           NaN         live
# 917564   PMC4205799  25316704.0           NaN         live
#
#                                        File  \
# 1053358  oa_package/5f/28/PMC4440621.tar.gz
# 838515   oa_package/9a/44/PMC4063513.tar.gz
# 2045390  oa_package/90/fc/PMC5947777.tar.gz
# 802598   oa_package/95/59/PMC3998579.tar.gz
# 281606   oa_package/c3/75/PMC2960533.tar.gz
# 292723   oa_package/51/3b/PMC2980240.tar.gz
# 323127   oa_package/5c/ec/PMC3050273.tar.gz
# 342917   oa_package/2c/84/PMC3099758.tar.gz
# 343177   oa_package/e0/08/PMC3100018.tar.gz
# 947604   oa_package/a1/65/PMC4257430.tar.gz
# 303823   oa_package/ae/05/PMC3007392.tar.gz
# 947555   oa_package/d5/d6/PMC4257381.tar.gz
# 280441   oa_package/68/f9/PMC2959367.tar.gz
# 292468   oa_package/4b/e4/PMC2979985.tar.gz
# 306512   oa_package/c0/95/PMC3011755.tar.gz
# 281045   oa_package/a0/8e/PMC2959972.tar.gz
# 411194   oa_package/fa/86/PMC3247338.tar.gz
# 287847   oa_package/ec/13/PMC2970339.tar.gz
# 323879   oa_package/9f/bb/PMC3051554.tar.gz
# 281861   oa_package/59/d5/PMC2960788.tar.gz
# 690612   oa_package/8f/f2/PMC3793720.tar.gz
# 365756   oa_package/2e/14/PMC3151776.tar.gz
# 394203   oa_package/46/03/PMC3213611.tar.gz
# 388050   oa_package/99/8f/PMC3200773.tar.gz
# 461935   oa_package/eb/2a/PMC3343840.tar.gz
# 523590   oa_package/07/e5/PMC3470182.tar.gz
# 303861   oa_package/96/46/PMC3007430.tar.gz
# 291793   oa_package/0d/f8/PMC2979260.tar.gz
# 480744   oa_package/3a/91/PMC3379412.tar.gz
# 304971   oa_package/74/49/PMC3009198.tar.gz
# ...                                     ...
# 2121012  oa_package/b5/82/PMC6056253.tar.gz
# 1320973  oa_package/4f/85/PMC4890279.tar.gz
# 1682460  oa_package/9d/97/PMC5416685.tar.gz
# 1049605  oa_package/8e/ed/PMC4434529.tar.gz
# 799147   oa_package/6b/58/PMC3992807.tar.gz
# 1418231  oa_package/08/43/PMC5048700.tar.gz
# 591087   oa_package/be/14/PMC3597278.tar.gz
# 331741   oa_package/bc/24/PMC3070673.tar.gz
# 196132   oa_package/0a/18/PMC2697159.tar.gz
# 1926924  oa_package/68/7a/PMC5776491.tar.gz
# 1399474  oa_package/57/30/PMC5020798.tar.gz
# 568552   oa_package/df/dc/PMC3555394.tar.gz
# 568510   oa_package/1a/2d/PMC3555352.tar.gz
# 1839005  oa_package/c5/fc/PMC5650002.tar.gz
# 215588   oa_package/50/b6/PMC2761909.tar.gz
# 2121012                2018-07-31 16:29:35        CC BY      False
# 1320973                2016-06-04 21:54:30        CC BY      False
# 1682460                2017-05-16 20:08:19        CC BY      False
# 1049605                2015-05-18 20:08:56        CC BY      False
# 799147                 2014-04-23 14:40:30  CC BY-NC-SA      False
# 1418231                2016-10-13 18:47:46  CC BY-NC-SA      False
# 591087                 2013-03-24 08:13:33   NO-CC CODE      False
# 331741                 2013-03-28 05:58:59        CC BY      False
# 196132                 2014-03-17 11:38:46        CC BY      False
# 1926924                2018-01-25 17:32:50  CC BY-NC-SA      False
# 1399474                2016-09-22 18:35:05  CC BY-NC-SA      False
# 568552                 2013-02-02 18:15:54  CC BY-NC-SA      False
# 568510                 2013-02-02 17:22:39  CC BY-NC-SA      False
# 1839005                2017-11-18 19:53:14     CC BY-NC      False
# 215588                 2013-04-03 16:06:10        CC BY      False
# 539161                 2015-05-04 19:27:32        CC BY      False
# 1540152                2017-01-09 19:08:39        CC BY      False
# 216018                 2009-10-16 20:25:11        CC BY      False
# 375076                 2013-03-28 07:47:47        CC BY      False
# 170998                 2011-03-29 17:53:18   NO-CC CODE      False
# 298927                 2010-12-16 11:53:20     CC BY-NC      False
# 175187                 2013-04-03 13:54:23     CC BY-NC      False
# 845208                 2014-06-30 20:14:20     CC BY-NC      False
# 175168                 2012-12-13 02:55:51     CC BY-NC      False
# 176650                 2013-04-03 13:56:43     CC BY-NC      False
# 1231335                2016-02-29 19:12:39     CC BY-NC      False
# 665051                 2013-08-31 20:13:39     CC BY-NC      False
# 1626017                2018-05-10 11:06:24        CC BY      False
# 1408592                2019-01-11 15:56:07        CC BY      False
# 917564                 2014-10-24 20:07:40  CC BY-NC-SA      False
#
# [1154 rows x 17 columns]

# %%
# Data we are working with
sample_df = retracted.append(control_sample)

# %%
# Get full text
print('START')
start = clock()
sample_df['Text'] = sample_df['PMCID'].map(get_full_text_by_pmcid)
stop = clock()
print("Time elapsed =", floor((stop-start)/60), "minute(s), and", round((stop-start)%60, 1), "second(s)")
# Out:
# START
# Time elapsed = 4 minute(s), and 4.6 second(s)

# %%
# Add gunning fog, takes ~2 minutes
print('START')
start = clock()
sample_df['gunning_fog'] = sample_df['Text'].map(textstat.gunning_fog)
stop = clock()
print("Time elapsed =", floor((stop-start)/60), "minute(s), and", round((stop-start)%60, 1), "second(s)")
# Out:
# START
# Time elapsed = 2 minute(s), and 1.2 second(s)

# %%
sample_df.to_csv('full-sample.csv', sep=',', encoding='utf-8', index=False)

# %%
# Takes 16 seconds for 5, so ~1 hour for whole set.
# print('START')
# start = clock()
# lst = []
# for text in sample_df['Text'][0:5]:
# # for text in sample_df.text:
#     res = sentiment_analyzer_scores(text)
#     lst.append(res)
# stop = clock()
# print("Time elapsed =", floor ((stop-start)/60), "minute(s), and", round((stop-start)%60, 1), "second(s)")

# %%
tp = sample_df

# %%
# tmp = tp.iloc[0:5,].copy()
# print('START')
# start = clock()
# tmp[['pos', 'neg', 'neu']] = tmp.apply(lambda row: sentiment_analyzer_scores(r['Text']), axis=1)
# stop = clock()
# print("Time elapsed =", floor ((stop-start)/60), "minute(s), and", round((stop-start)%60, 1), "second(s)")
